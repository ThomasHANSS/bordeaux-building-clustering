# %% [markdown]
# # 05 — Stabilité des clusters
#
# Bootstrap, ARI, analyse de robustesse.

# %%
from src.config import setup_project
from src.evaluation import bootstrap_stability

cfg = setup_project()

# %%
# Stabilité bootstrap
# result = bootstrap_stability(X, n_clusters=15, n_bootstrap=50)
# print(f"ARI moyen : {result['ari_mean']:.3f} ± {result['ari_std']:.3f}")

# %%
# Distribution des ARI
# import matplotlib.pyplot as plt
# plt.hist(result['ari_scores'], bins=20, edgecolor='black')
# plt.xlabel('ARI')
# plt.ylabel('Fréquence')
# plt.title('Stabilité bootstrap')
# plt.axvline(result['ari_mean'], color='red', linestyle='--')
# plt.show()
