# %% [markdown]
# # 01 — Exploration BDNB
#
# Audit du schéma, complétude, distributions.
# Objectif : compléter le `column_mapping` dans `config.yaml`.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import setup_project, PROJECT_ROOT

cfg = setup_project()

# %%
# Charger les données brutes
# Adapter le chemin et le format selon ce qui a été téléchargé
bdnb_path = PROJECT_ROOT / 'data' / 'raw' / 'bdnb_33'
print('Fichiers disponibles :')
for f in bdnb_path.iterdir():
    print(f'  {f.name} ({f.stat().st_size / 1e6:.1f} Mo)')

# %%
# Explorer le schéma
# df = pd.read_csv('...', nrows=100)
# print(df.columns.tolist())
# print(df.dtypes)
# print(df.describe())

# %%
# Audit de complétude
# from src.features import audit_completeness
# audit = audit_completeness(gdf, cfg)
# audit.head(20)

# %% [markdown]
# # TODO : Compléter config.yaml → features.column_mapping
# # avec les vrais noms de colonnes découverts ci-dessus
