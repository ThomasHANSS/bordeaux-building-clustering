# %% [markdown]
# # 03 — Corrélations et réduction de dimension
#
# Analyse des corrélations, VIF, PCA/UMAP optionnel.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from src.config import setup_project
from src.feature_selection import select_features

cfg = setup_project()

# %%
# Matrice de corrélation avant sélection
# import geopandas as gpd
# from src.config import PROJECT_ROOT
# gdf = gpd.read_parquet(PROJECT_ROOT / cfg['pipeline']['intermediate_file'])
# corr = gdf.drop(columns=['uid', 'geometry']).corr()
# plt.figure(figsize=(12, 10))
# sns.heatmap(corr, annot=True, fmt='.2f', cmap='RdBu_r', center=0)
# plt.title('Matrice de corrélation')
# plt.tight_layout()
# plt.show()

# %%
# Sélection
# gdf_selected = select_features(cfg)
# print(f'Features retenues : {len(gdf_selected.columns) - 2}')
