# %% [markdown]
# # 02 — Feature Engineering
#
# Construction et validation des features.

# %%
from src.config import setup_project
from src.features import build_features

cfg = setup_project()

# %%
# Construire les features
gdf = build_features(cfg)
print(f'{len(gdf)} bâtiments, {len(gdf.columns)} colonnes')
gdf.head()

# %%
# Distributions des features
# import matplotlib.pyplot as plt
# gdf.drop(columns=['geometry', 'uid']).hist(figsize=(16, 12), bins=50)
# plt.tight_layout()
# plt.show()
