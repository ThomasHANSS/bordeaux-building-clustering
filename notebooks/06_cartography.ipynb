# %% [markdown]
# # 06 — Cartographie
#
# Cartes interactives et statiques des clusters.

# %%
from src.config import setup_project
from src.mapping import generate_maps, create_folium_map
from src.spatial_analysis import compute_moran_i
import geopandas as gpd

cfg = setup_project()

# %%
# Charger les résultats
# from src.config import PROJECT_ROOT
# gdf = gpd.read_parquet(PROJECT_ROOT / cfg['pipeline']['results_file'])

# %%
# Moran's I
# moran = compute_moran_i(gdf)
# print(f"Moran's I : {moran['moran_i']:.3f} (p={moran['p_value']:.4f})")

# %% [markdown]
# # Générer toutes les cartes
# # generate_maps(cfg)

# %% [markdown]
# # Validation visuelle
# # Zoomer sur :
# # - Centre historique Bordeaux
# # - Mériadeck
# # - Caudéran / Le Bouscat
# # - Bassins à flot / Euratlantique
# # - Zone activité Pessac-Bersol
