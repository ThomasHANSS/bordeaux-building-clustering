# %% [markdown]
# # 04 — Comparaison des clusterings
#
# Test des 4 algorithmes, visualisation des résultats.

# %%
import matplotlib.pyplot as plt
import numpy as np
from src.config import setup_project
from src.clustering import run_clustering

cfg = setup_project()

# %%
# Lancer le clustering complet
# gdf = run_clustering(cfg)

# %%
# Visualisation UMAP 2D des clusters
# import umap
# reducer = umap.UMAP(n_components=2, random_state=42)
# embedding = reducer.fit_transform(X)
# plt.figure(figsize=(12, 10))
# plt.scatter(embedding[:, 0], embedding[:, 1], c=labels, cmap='tab20', s=1, alpha=0.5)
# plt.colorbar()
# plt.title('UMAP — Clusters')
# plt.show()

# %%
# Comparaison des runs
# import json
# from src.evaluation import compare_runs
# with open('outputs/experiments.json') as f:
#     exp = json.load(f)
# print(compare_runs(exp))
